# %% [markdown]
# # Converting Tensorflow model into a Core ML model

# %% [markdown]
# ## 1. Install coremltools

# %%
# !pip install --upgrade tfcoreml
# !pip install --upgrade coremltools
# Out:
# Collecting tfcoreml
#   Downloading https://files.pythonhosted.org/packages/5a/d0/26a1156ccc831ce68d0c17c249787721451b111805505f0aa42a8fd66aae/tfcoreml-1.1-py3-none-any.whl (44kB)
#      |████████████████████████████████| 51kB 1.6MB/s
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tfcoreml) (1.12.0)
# Collecting coremltools>=0.8
#   Downloading https://files.pythonhosted.org/packages/af/f8/ac6940600864b08476fee09583b7c66e2fcfe70ccafeb696710103c4a31b/coremltools-3.1-cp36-none-manylinux1_x86_64.whl (3.4MB)
#      |████████████████████████████████| 3.4MB 7.7MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.6.2 in /usr/local/lib/python3.6/dist-packages (from tfcoreml) (1.17.4)
# Requirement already satisfied, skipping upgrade: tensorflow>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from tfcoreml) (1.15.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.1.0 in /usr/local/lib/python3.6/dist-packages (from tfcoreml) (3.10.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (0.8.1)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (0.1.8)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (1.1.0)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (0.2.2)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (1.11.2)
# Requirement already satisfied, skipping upgrade: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (1.15.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (1.15.1)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (1.15.0)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (3.1.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (1.0.8)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (0.33.6)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->tfcoreml) (0.8.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.1.0->tfcoreml) (41.6.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow>=1.5.0->tfcoreml) (3.1.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow>=1.5.0->tfcoreml) (0.16.0)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow>=1.5.0->tfcoreml) (2.8.0)
# Installing collected packages: coremltools, tfcoreml
# Successfully installed coremltools-3.1 tfcoreml-1.1
# Requirement already up-to-date: coremltools in /usr/local/lib/python3.6/dist-packages (3.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from coremltools) (1.17.4)
# Requirement already satisfied, skipping upgrade: protobuf>=3.1.0 in /usr/local/lib/python3.6/dist-packages (from coremltools) (3.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from coremltools) (1.12.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.1.0->coremltools) (41.6.0)

# %%
from __future__ import print_function
import  os, sys, zipfile
from os.path import dirname
import numpy as np
import tensorflow as tf
from tensorflow.core.framework import graph_pb2
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## 3. Download the model and class label package
# First we'll download the frozen TensorFlow model and unzip it.
#
#
# url = The URL address of the frozen file
#
# dir_path = local directory

# %%
# Download the model and class label package
def download_file_and_unzip(url, dir_path='.'):

    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    k = url.rfind('/')
    fname = url[k+1:]
    fpath = os.path.join(dir_path, fname)

    if not os.path.exists(fpath):
        if sys.version_info[0] < 3:
            import urllib
            urllib.urlretrieve(url, fpath)
        else:
            import urllib.request
            urllib.request.urlretrieve(url, fpath)

    zip_ref = zipfile.ZipFile(fpath, 'r')
    zip_ref.extractall(dir_path)
    zip_ref.close()

inception_v3_url = 'https://storage.googleapis.com/download.tensorflow.org/models/inception_dec_2015.zip'
download_file_and_unzip(inception_v3_url);

# %% [markdown]
# ##4. Load the TF graph definition

# %%
tf_model_path = './tensorflow_inception_graph.pb'
with open(tf_model_path, 'rb') as f:
    serialized = f.read()
tf.reset_default_graph()
original_gdef = tf.GraphDef()
original_gdef.ParseFromString(serialized)

# For demonstration purpose we show the first 15 ops the TF model
with tf.Graph().as_default() as g:
    tf.import_graph_def(original_gdef, name='')
    ops = g.get_operations()
    for i in range(15):
        print('op id {} : op name: {}, op type: "{}"'.format(str(i),ops[i].name, ops[i].type));

# This Inception model uses DecodeJpeg op to read from JPEG images
# encoded as string Tensors. You can visualize it with TensorBoard,
# but we're omitting it here. For deployment we need to remove the
# JPEG decoder and related ops, and replace them with a placeholder
# where we can feed image data in.
# Out:
# op id 0 : op name: DecodeJpeg/contents, op type: "Const"
# op id 1 : op name: DecodeJpeg, op type: "DecodeJpeg"
# op id 2 : op name: Cast, op type: "Cast"
# op id 3 : op name: ExpandDims/dim, op type: "Const"
# op id 4 : op name: ExpandDims, op type: "ExpandDims"
# op id 5 : op name: ResizeBilinear/size, op type: "Const"
# op id 6 : op name: ResizeBilinear, op type: "ResizeBilinear"
# op id 7 : op name: Sub/y, op type: "Const"
# op id 8 : op name: Sub, op type: "Sub"
# op id 9 : op name: Mul/y, op type: "Const"
# op id 10 : op name: Mul, op type: "Mul"
# op id 11 : op name: conv/conv2d_params, op type: "Const"
# op id 12 : op name: conv/Conv2D, op type: "Conv2D"
# op id 13 : op name: conv/batchnorm/beta, op type: "Const"
# op id 14 : op name: conv/batchnorm/gamma, op type: "Const"

# %% [markdown]
# ## 5. Strip the decoder and prepocessing part
# In this model, the actual op that feeds pre-processed image into the network is 'Mul'. The op that generates probabilities per class is 'softmax/logits'. To figure out what are inputs/outputs for your own model you can use use TensorFlow's summarize_graph or TensorBoard visualization tool for your own models.

# %%
from tensorflow.python.tools import strip_unused_lib
from tensorflow.python.framework import dtypes
from tensorflow.python.platform import gfile
input_node_names = ['Mul']
output_node_names = ['softmax/logits']
gdef = strip_unused_lib.strip_unused(
        input_graph_def = original_gdef,
        input_node_names = input_node_names,
        output_node_names = output_node_names,
        placeholder_type_enum = dtypes.float32.as_datatype_enum)
# Save it to an output file
frozen_model_file = './inception_v3.pb'
with gfile.GFile(frozen_model_file, "wb") as f:
    f.write(gdef.SerializeToString())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/strip_unused_lib.py:88: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`

# %% [markdown]
# ## 6.Convert to CoreML

# %%
# Now we have a TF model ready to be converted to CoreML
import tfcoreml
# Supply a dictionary of input tensors' name and shape (with 
# batch axis)
input_tensor_shapes = {"Mul:0":[1,299,299,3]} # batch size is 1
# Output CoreML model path
coreml_model_file = './inception_v3.mlmodel'
# The TF model's ouput tensor name
output_tensor_names = ['softmax/logits:0']

# Call the converter.
coreml_model = tfcoreml.convert(
        tf_model_path=frozen_model_file,
        mlmodel_path=coreml_model_file,
        input_name_shape_dict=input_tensor_shapes,
        output_feature_names=output_tensor_names,
        image_input_names = ['Mul:0'],
        red_bias = -1,
        green_bias = -1,
        blue_bias = -1,
        image_scale = 2.0/255.0)

# MLModel saved at location: ./inception_v3.mlmodel
# Out:
# WARNING:root:TensorFlow version 1.15.0 detected. Last version known to be fully compatible is 1.14.0 .
# WARNING:root:Keras version 2.2.5 detected. Last version known to be fully compatible of Keras is 2.2.4 .
# Loading the TF graph...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tfcoreml/_tf_coreml_converter.py:221: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tfcoreml/_tf_coreml_converter.py:221: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# Collecting all the 'Const' ops from the graph, by running it....
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob Mul:0
# 1/993: Analysing op name: softmax/biases ( type:  Const )
# 2/993: Analysing op name: softmax/weights ( type:  Const )
# 3/993: Analysing op name: pool_3/_reshape/shape ( type:  Const )
# 4/993: Analysing op name: mixed_10/join/concat_dim ( type:  Const )
# 5/993: Analysing op name: mixed_10/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 6/993: Analysing op name: mixed_10/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 7/993: Analysing op name: mixed_10/tower_2/conv/batchnorm/gamma ( type:  Const )
# 8/993: Analysing op name: mixed_10/tower_2/conv/batchnorm/beta ( type:  Const )
# 9/993: Analysing op name: mixed_10/tower_2/conv/conv2d_params ( type:  Const )
# 10/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/batchnorm/moving_variance ( type:  Const )
# 11/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/batchnorm/moving_mean ( type:  Const )
# 12/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/batchnorm/gamma ( type:  Const )
# 13/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/batchnorm/beta ( type:  Const )
# 14/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/conv2d_params ( type:  Const )
# 15/993: Analysing op name: mixed_10/tower_1/mixed/conv/batchnorm/moving_variance ( type:  Const )
# 16/993: Analysing op name: mixed_10/tower_1/mixed/conv/batchnorm/moving_mean ( type:  Const )
# 17/993: Analysing op name: mixed_10/tower_1/mixed/conv/batchnorm/gamma ( type:  Const )
# 18/993: Analysing op name: mixed_10/tower_1/mixed/conv/batchnorm/beta ( type:  Const )
# 19/993: Analysing op name: mixed_10/tower_1/mixed/conv/conv2d_params ( type:  Const )
# 20/993: Analysing op name: mixed_10/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 21/993: Analysing op name: mixed_10/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 22/993: Analysing op name: mixed_10/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 23/993: Analysing op name: mixed_10/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 24/993: Analysing op name: mixed_10/tower_1/conv_1/conv2d_params ( type:  Const )
# 25/993: Analysing op name: mixed_10/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 26/993: Analysing op name: mixed_10/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 27/993: Analysing op name: mixed_10/tower_1/conv/batchnorm/gamma ( type:  Const )
# 28/993: Analysing op name: mixed_10/tower_1/conv/batchnorm/beta ( type:  Const )
# 29/993: Analysing op name: mixed_10/tower_1/conv/conv2d_params ( type:  Const )
# 30/993: Analysing op name: mixed_10/tower/mixed/conv_1/batchnorm/moving_variance ( type:  Const )
# 31/993: Analysing op name: mixed_10/tower/mixed/conv_1/batchnorm/moving_mean ( type:  Const )
# 32/993: Analysing op name: mixed_10/tower/mixed/conv_1/batchnorm/gamma ( type:  Const )
# 33/993: Analysing op name: mixed_10/tower/mixed/conv_1/batchnorm/beta ( type:  Const )
# 34/993: Analysing op name: mixed_10/tower/mixed/conv_1/conv2d_params ( type:  Const )
# 35/993: Analysing op name: mixed_10/tower/mixed/conv/batchnorm/moving_variance ( type:  Const )
# 36/993: Analysing op name: mixed_10/tower/mixed/conv/batchnorm/moving_mean ( type:  Const )
# 37/993: Analysing op name: mixed_10/tower/mixed/conv/batchnorm/gamma ( type:  Const )
# 38/993: Analysing op name: mixed_10/tower/mixed/conv/batchnorm/beta ( type:  Const )
# 39/993: Analysing op name: mixed_10/tower/mixed/conv/conv2d_params ( type:  Const )
# 40/993: Analysing op name: mixed_10/tower/conv/batchnorm/moving_variance ( type:  Const )
# 41/993: Analysing op name: mixed_10/tower/conv/batchnorm/moving_mean ( type:  Const )
# 42/993: Analysing op name: mixed_10/tower/conv/batchnorm/gamma ( type:  Const )
# 43/993: Analysing op name: mixed_10/tower/conv/batchnorm/beta ( type:  Const )
# 44/993: Analysing op name: mixed_10/tower/conv/conv2d_params ( type:  Const )
# 45/993: Analysing op name: mixed_10/conv/batchnorm/moving_variance ( type:  Const )
# 46/993: Analysing op name: mixed_10/conv/batchnorm/moving_mean ( type:  Const )
# 47/993: Analysing op name: mixed_10/conv/batchnorm/gamma ( type:  Const )
# 48/993: Analysing op name: mixed_10/conv/batchnorm/beta ( type:  Const )
# 49/993: Analysing op name: mixed_10/conv/conv2d_params ( type:  Const )
# 50/993: Analysing op name: mixed_9/join/concat_dim ( type:  Const )
# 51/993: Analysing op name: mixed_9/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 52/993: Analysing op name: mixed_9/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 53/993: Analysing op name: mixed_9/tower_2/conv/batchnorm/gamma ( type:  Const )
# 54/993: Analysing op name: mixed_9/tower_2/conv/batchnorm/beta ( type:  Const )
# 55/993: Analysing op name: mixed_9/tower_2/conv/conv2d_params ( type:  Const )
# 56/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/batchnorm/moving_variance ( type:  Const )
# 57/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/batchnorm/moving_mean ( type:  Const )
# 58/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/batchnorm/gamma ( type:  Const )
# 59/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/batchnorm/beta ( type:  Const )
# 60/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/conv2d_params ( type:  Const )
# 61/993: Analysing op name: mixed_9/tower_1/mixed/conv/batchnorm/moving_variance ( type:  Const )
# 62/993: Analysing op name: mixed_9/tower_1/mixed/conv/batchnorm/moving_mean ( type:  Const )
# 63/993: Analysing op name: mixed_9/tower_1/mixed/conv/batchnorm/gamma ( type:  Const )
# 64/993: Analysing op name: mixed_9/tower_1/mixed/conv/batchnorm/beta ( type:  Const )
# 65/993: Analysing op name: mixed_9/tower_1/mixed/conv/conv2d_params ( type:  Const )
# 66/993: Analysing op name: mixed_9/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 67/993: Analysing op name: mixed_9/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 68/993: Analysing op name: mixed_9/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 69/993: Analysing op name: mixed_9/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 70/993: Analysing op name: mixed_9/tower_1/conv_1/conv2d_params ( type:  Const )
# 71/993: Analysing op name: mixed_9/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 72/993: Analysing op name: mixed_9/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 73/993: Analysing op name: mixed_9/tower_1/conv/batchnorm/gamma ( type:  Const )
# 74/993: Analysing op name: mixed_9/tower_1/conv/batchnorm/beta ( type:  Const )
# 75/993: Analysing op name: mixed_9/tower_1/conv/conv2d_params ( type:  Const )
# 76/993: Analysing op name: mixed_9/tower/mixed/conv_1/batchnorm/moving_variance ( type:  Const )
# 77/993: Analysing op name: mixed_9/tower/mixed/conv_1/batchnorm/moving_mean ( type:  Const )
# 78/993: Analysing op name: mixed_9/tower/mixed/conv_1/batchnorm/gamma ( type:  Const )
# 79/993: Analysing op name: mixed_9/tower/mixed/conv_1/batchnorm/beta ( type:  Const )
# 80/993: Analysing op name: mixed_9/tower/mixed/conv_1/conv2d_params ( type:  Const )
# 81/993: Analysing op name: mixed_9/tower/mixed/conv/batchnorm/moving_variance ( type:  Const )
# 82/993: Analysing op name: mixed_9/tower/mixed/conv/batchnorm/moving_mean ( type:  Const )
# 83/993: Analysing op name: mixed_9/tower/mixed/conv/batchnorm/gamma ( type:  Const )
# 84/993: Analysing op name: mixed_9/tower/mixed/conv/batchnorm/beta ( type:  Const )
# 85/993: Analysing op name: mixed_9/tower/mixed/conv/conv2d_params ( type:  Const )
# 86/993: Analysing op name: mixed_9/tower/conv/batchnorm/moving_variance ( type:  Const )
# 87/993: Analysing op name: mixed_9/tower/conv/batchnorm/moving_mean ( type:  Const )
# 88/993: Analysing op name: mixed_9/tower/conv/batchnorm/gamma ( type:  Const )
# 89/993: Analysing op name: mixed_9/tower/conv/batchnorm/beta ( type:  Const )
# 90/993: Analysing op name: mixed_9/tower/conv/conv2d_params ( type:  Const )
# 91/993: Analysing op name: mixed_9/conv/batchnorm/moving_variance ( type:  Const )
# 92/993: Analysing op name: mixed_9/conv/batchnorm/moving_mean ( type:  Const )
# 93/993: Analysing op name: mixed_9/conv/batchnorm/gamma ( type:  Const )
# 94/993: Analysing op name: mixed_9/conv/batchnorm/beta ( type:  Const )
# 95/993: Analysing op name: mixed_9/conv/conv2d_params ( type:  Const )
# 96/993: Analysing op name: mixed_8/join/concat_dim ( type:  Const )
# 97/993: Analysing op name: mixed_8/tower_1/conv_3/batchnorm/moving_variance ( type:  Const )
# 98/993: Analysing op name: mixed_8/tower_1/conv_3/batchnorm/moving_mean ( type:  Const )
# 99/993: Analysing op name: mixed_8/tower_1/conv_3/batchnorm/gamma ( type:  Const )
# 100/993: Analysing op name: mixed_8/tower_1/conv_3/batchnorm/beta ( type:  Const )
# 101/993: Analysing op name: mixed_8/tower_1/conv_3/conv2d_params ( type:  Const )
# 102/993: Analysing op name: mixed_8/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 103/993: Analysing op name: mixed_8/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 104/993: Analysing op name: mixed_8/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 105/993: Analysing op name: mixed_8/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 106/993: Analysing op name: mixed_8/tower_1/conv_2/conv2d_params ( type:  Const )
# 107/993: Analysing op name: mixed_8/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 108/993: Analysing op name: mixed_8/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 109/993: Analysing op name: mixed_8/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 110/993: Analysing op name: mixed_8/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 111/993: Analysing op name: mixed_8/tower_1/conv_1/conv2d_params ( type:  Const )
# 112/993: Analysing op name: mixed_8/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 113/993: Analysing op name: mixed_8/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 114/993: Analysing op name: mixed_8/tower_1/conv/batchnorm/gamma ( type:  Const )
# 115/993: Analysing op name: mixed_8/tower_1/conv/batchnorm/beta ( type:  Const )
# 116/993: Analysing op name: mixed_8/tower_1/conv/conv2d_params ( type:  Const )
# 117/993: Analysing op name: mixed_8/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 118/993: Analysing op name: mixed_8/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 119/993: Analysing op name: mixed_8/tower/conv_1/batchnorm/gamma ( type:  Const )
# 120/993: Analysing op name: mixed_8/tower/conv_1/batchnorm/beta ( type:  Const )
# 121/993: Analysing op name: mixed_8/tower/conv_1/conv2d_params ( type:  Const )
# 122/993: Analysing op name: mixed_8/tower/conv/batchnorm/moving_variance ( type:  Const )
# 123/993: Analysing op name: mixed_8/tower/conv/batchnorm/moving_mean ( type:  Const )
# 124/993: Analysing op name: mixed_8/tower/conv/batchnorm/gamma ( type:  Const )
# 125/993: Analysing op name: mixed_8/tower/conv/batchnorm/beta ( type:  Const )
# 126/993: Analysing op name: mixed_8/tower/conv/conv2d_params ( type:  Const )
# 127/993: Analysing op name: mixed_7/join/concat_dim ( type:  Const )
# 128/993: Analysing op name: mixed_7/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 129/993: Analysing op name: mixed_7/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 130/993: Analysing op name: mixed_7/tower_2/conv/batchnorm/gamma ( type:  Const )
# 131/993: Analysing op name: mixed_7/tower_2/conv/batchnorm/beta ( type:  Const )
# 132/993: Analysing op name: mixed_7/tower_2/conv/conv2d_params ( type:  Const )
# 133/993: Analysing op name: mixed_7/tower_1/conv_4/batchnorm/moving_variance ( type:  Const )
# 134/993: Analysing op name: mixed_7/tower_1/conv_4/batchnorm/moving_mean ( type:  Const )
# 135/993: Analysing op name: mixed_7/tower_1/conv_4/batchnorm/gamma ( type:  Const )
# 136/993: Analysing op name: mixed_7/tower_1/conv_4/batchnorm/beta ( type:  Const )
# 137/993: Analysing op name: mixed_7/tower_1/conv_4/conv2d_params ( type:  Const )
# 138/993: Analysing op name: mixed_7/tower_1/conv_3/batchnorm/moving_variance ( type:  Const )
# 139/993: Analysing op name: mixed_7/tower_1/conv_3/batchnorm/moving_mean ( type:  Const )
# 140/993: Analysing op name: mixed_7/tower_1/conv_3/batchnorm/gamma ( type:  Const )
# 141/993: Analysing op name: mixed_7/tower_1/conv_3/batchnorm/beta ( type:  Const )
# 142/993: Analysing op name: mixed_7/tower_1/conv_3/conv2d_params ( type:  Const )
# 143/993: Analysing op name: mixed_7/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 144/993: Analysing op name: mixed_7/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 145/993: Analysing op name: mixed_7/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 146/993: Analysing op name: mixed_7/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 147/993: Analysing op name: mixed_7/tower_1/conv_2/conv2d_params ( type:  Const )
# 148/993: Analysing op name: mixed_7/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 149/993: Analysing op name: mixed_7/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 150/993: Analysing op name: mixed_7/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 151/993: Analysing op name: mixed_7/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 152/993: Analysing op name: mixed_7/tower_1/conv_1/conv2d_params ( type:  Const )
# 153/993: Analysing op name: mixed_7/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 154/993: Analysing op name: mixed_7/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 155/993: Analysing op name: mixed_7/tower_1/conv/batchnorm/gamma ( type:  Const )
# 156/993: Analysing op name: mixed_7/tower_1/conv/batchnorm/beta ( type:  Const )
# 157/993: Analysing op name: mixed_7/tower_1/conv/conv2d_params ( type:  Const )
# 158/993: Analysing op name: mixed_7/tower/conv_2/batchnorm/moving_variance ( type:  Const )
# 159/993: Analysing op name: mixed_7/tower/conv_2/batchnorm/moving_mean ( type:  Const )
# 160/993: Analysing op name: mixed_7/tower/conv_2/batchnorm/gamma ( type:  Const )
# 161/993: Analysing op name: mixed_7/tower/conv_2/batchnorm/beta ( type:  Const )
# 162/993: Analysing op name: mixed_7/tower/conv_2/conv2d_params ( type:  Const )
# 163/993: Analysing op name: mixed_7/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 164/993: Analysing op name: mixed_7/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 165/993: Analysing op name: mixed_7/tower/conv_1/batchnorm/gamma ( type:  Const )
# 166/993: Analysing op name: mixed_7/tower/conv_1/batchnorm/beta ( type:  Const )
# 167/993: Analysing op name: mixed_7/tower/conv_1/conv2d_params ( type:  Const )
# 168/993: Analysing op name: mixed_7/tower/conv/batchnorm/moving_variance ( type:  Const )
# 169/993: Analysing op name: mixed_7/tower/conv/batchnorm/moving_mean ( type:  Const )
# 170/993: Analysing op name: mixed_7/tower/conv/batchnorm/gamma ( type:  Const )
# 171/993: Analysing op name: mixed_7/tower/conv/batchnorm/beta ( type:  Const )
# 172/993: Analysing op name: mixed_7/tower/conv/conv2d_params ( type:  Const )
# 173/993: Analysing op name: mixed_7/conv/batchnorm/moving_variance ( type:  Const )
# 174/993: Analysing op name: mixed_7/conv/batchnorm/moving_mean ( type:  Const )
# 175/993: Analysing op name: mixed_7/conv/batchnorm/gamma ( type:  Const )
# 176/993: Analysing op name: mixed_7/conv/batchnorm/beta ( type:  Const )
# 177/993: Analysing op name: mixed_7/conv/conv2d_params ( type:  Const )
# 178/993: Analysing op name: mixed_6/join/concat_dim ( type:  Const )
# 179/993: Analysing op name: mixed_6/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 180/993: Analysing op name: mixed_6/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 181/993: Analysing op name: mixed_6/tower_2/conv/batchnorm/gamma ( type:  Const )
# 182/993: Analysing op name: mixed_6/tower_2/conv/batchnorm/beta ( type:  Const )
# 183/993: Analysing op name: mixed_6/tower_2/conv/conv2d_params ( type:  Const )
# 184/993: Analysing op name: mixed_6/tower_1/conv_4/batchnorm/moving_variance ( type:  Const )
# 185/993: Analysing op name: mixed_6/tower_1/conv_4/batchnorm/moving_mean ( type:  Const )
# 186/993: Analysing op name: mixed_6/tower_1/conv_4/batchnorm/gamma ( type:  Const )
# 187/993: Analysing op name: mixed_6/tower_1/conv_4/batchnorm/beta ( type:  Const )
# 188/993: Analysing op name: mixed_6/tower_1/conv_4/conv2d_params ( type:  Const )
# 189/993: Analysing op name: mixed_6/tower_1/conv_3/batchnorm/moving_variance ( type:  Const )
# 190/993: Analysing op name: mixed_6/tower_1/conv_3/batchnorm/moving_mean ( type:  Const )
# 191/993: Analysing op name: mixed_6/tower_1/conv_3/batchnorm/gamma ( type:  Const )
# 192/993: Analysing op name: mixed_6/tower_1/conv_3/batchnorm/beta ( type:  Const )
# 193/993: Analysing op name: mixed_6/tower_1/conv_3/conv2d_params ( type:  Const )
# 194/993: Analysing op name: mixed_6/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 195/993: Analysing op name: mixed_6/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 196/993: Analysing op name: mixed_6/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 197/993: Analysing op name: mixed_6/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 198/993: Analysing op name: mixed_6/tower_1/conv_2/conv2d_params ( type:  Const )
# 199/993: Analysing op name: mixed_6/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 200/993: Analysing op name: mixed_6/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 201/993: Analysing op name: mixed_6/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 202/993: Analysing op name: mixed_6/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 203/993: Analysing op name: mixed_6/tower_1/conv_1/conv2d_params ( type:  Const )
# 204/993: Analysing op name: mixed_6/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 205/993: Analysing op name: mixed_6/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 206/993: Analysing op name: mixed_6/tower_1/conv/batchnorm/gamma ( type:  Const )
# 207/993: Analysing op name: mixed_6/tower_1/conv/batchnorm/beta ( type:  Const )
# 208/993: Analysing op name: mixed_6/tower_1/conv/conv2d_params ( type:  Const )
# 209/993: Analysing op name: mixed_6/tower/conv_2/batchnorm/moving_variance ( type:  Const )
# 210/993: Analysing op name: mixed_6/tower/conv_2/batchnorm/moving_mean ( type:  Const )
# 211/993: Analysing op name: mixed_6/tower/conv_2/batchnorm/gamma ( type:  Const )
# 212/993: Analysing op name: mixed_6/tower/conv_2/batchnorm/beta ( type:  Const )
# 213/993: Analysing op name: mixed_6/tower/conv_2/conv2d_params ( type:  Const )
# 214/993: Analysing op name: mixed_6/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 215/993: Analysing op name: mixed_6/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 216/993: Analysing op name: mixed_6/tower/conv_1/batchnorm/gamma ( type:  Const )
# 217/993: Analysing op name: mixed_6/tower/conv_1/batchnorm/beta ( type:  Const )
# 218/993: Analysing op name: mixed_6/tower/conv_1/conv2d_params ( type:  Const )
# 219/993: Analysing op name: mixed_6/tower/conv/batchnorm/moving_variance ( type:  Const )
# 220/993: Analysing op name: mixed_6/tower/conv/batchnorm/moving_mean ( type:  Const )
# 221/993: Analysing op name: mixed_6/tower/conv/batchnorm/gamma ( type:  Const )
# 222/993: Analysing op name: mixed_6/tower/conv/batchnorm/beta ( type:  Const )
# 223/993: Analysing op name: mixed_6/tower/conv/conv2d_params ( type:  Const )
# 224/993: Analysing op name: mixed_6/conv/batchnorm/moving_variance ( type:  Const )
# 225/993: Analysing op name: mixed_6/conv/batchnorm/moving_mean ( type:  Const )
# 226/993: Analysing op name: mixed_6/conv/batchnorm/gamma ( type:  Const )
# 227/993: Analysing op name: mixed_6/conv/batchnorm/beta ( type:  Const )
# 228/993: Analysing op name: mixed_6/conv/conv2d_params ( type:  Const )
# 229/993: Analysing op name: mixed_5/join/concat_dim ( type:  Const )
# 230/993: Analysing op name: mixed_5/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 231/993: Analysing op name: mixed_5/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 232/993: Analysing op name: mixed_5/tower_2/conv/batchnorm/gamma ( type:  Const )
# 233/993: Analysing op name: mixed_5/tower_2/conv/batchnorm/beta ( type:  Const )
# 234/993: Analysing op name: mixed_5/tower_2/conv/conv2d_params ( type:  Const )
# 235/993: Analysing op name: mixed_5/tower_1/conv_4/batchnorm/moving_variance ( type:  Const )
# 236/993: Analysing op name: mixed_5/tower_1/conv_4/batchnorm/moving_mean ( type:  Const )
# 237/993: Analysing op name: mixed_5/tower_1/conv_4/batchnorm/gamma ( type:  Const )
# 238/993: Analysing op name: mixed_5/tower_1/conv_4/batchnorm/beta ( type:  Const )
# 239/993: Analysing op name: mixed_5/tower_1/conv_4/conv2d_params ( type:  Const )
# 240/993: Analysing op name: mixed_5/tower_1/conv_3/batchnorm/moving_variance ( type:  Const )
# 241/993: Analysing op name: mixed_5/tower_1/conv_3/batchnorm/moving_mean ( type:  Const )
# 242/993: Analysing op name: mixed_5/tower_1/conv_3/batchnorm/gamma ( type:  Const )
# 243/993: Analysing op name: mixed_5/tower_1/conv_3/batchnorm/beta ( type:  Const )
# 244/993: Analysing op name: mixed_5/tower_1/conv_3/conv2d_params ( type:  Const )
# 245/993: Analysing op name: mixed_5/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 246/993: Analysing op name: mixed_5/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 247/993: Analysing op name: mixed_5/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 248/993: Analysing op name: mixed_5/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 249/993: Analysing op name: mixed_5/tower_1/conv_2/conv2d_params ( type:  Const )
# 250/993: Analysing op name: mixed_5/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 251/993: Analysing op name: mixed_5/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 252/993: Analysing op name: mixed_5/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 253/993: Analysing op name: mixed_5/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 254/993: Analysing op name: mixed_5/tower_1/conv_1/conv2d_params ( type:  Const )
# 255/993: Analysing op name: mixed_5/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 256/993: Analysing op name: mixed_5/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 257/993: Analysing op name: mixed_5/tower_1/conv/batchnorm/gamma ( type:  Const )
# 258/993: Analysing op name: mixed_5/tower_1/conv/batchnorm/beta ( type:  Const )
# 259/993: Analysing op name: mixed_5/tower_1/conv/conv2d_params ( type:  Const )
# 260/993: Analysing op name: mixed_5/tower/conv_2/batchnorm/moving_variance ( type:  Const )
# 261/993: Analysing op name: mixed_5/tower/conv_2/batchnorm/moving_mean ( type:  Const )
# 262/993: Analysing op name: mixed_5/tower/conv_2/batchnorm/gamma ( type:  Const )
# 263/993: Analysing op name: mixed_5/tower/conv_2/batchnorm/beta ( type:  Const )
# 264/993: Analysing op name: mixed_5/tower/conv_2/conv2d_params ( type:  Const )
# 265/993: Analysing op name: mixed_5/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 266/993: Analysing op name: mixed_5/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 267/993: Analysing op name: mixed_5/tower/conv_1/batchnorm/gamma ( type:  Const )
# 268/993: Analysing op name: mixed_5/tower/conv_1/batchnorm/beta ( type:  Const )
# 269/993: Analysing op name: mixed_5/tower/conv_1/conv2d_params ( type:  Const )
# 270/993: Analysing op name: mixed_5/tower/conv/batchnorm/moving_variance ( type:  Const )
# 271/993: Analysing op name: mixed_5/tower/conv/batchnorm/moving_mean ( type:  Const )
# 272/993: Analysing op name: mixed_5/tower/conv/batchnorm/gamma ( type:  Const )
# 273/993: Analysing op name: mixed_5/tower/conv/batchnorm/beta ( type:  Const )
# 274/993: Analysing op name: mixed_5/tower/conv/conv2d_params ( type:  Const )
# 275/993: Analysing op name: mixed_5/conv/batchnorm/moving_variance ( type:  Const )
# 276/993: Analysing op name: mixed_5/conv/batchnorm/moving_mean ( type:  Const )
# 277/993: Analysing op name: mixed_5/conv/batchnorm/gamma ( type:  Const )
# 278/993: Analysing op name: mixed_5/conv/batchnorm/beta ( type:  Const )
# 279/993: Analysing op name: mixed_5/conv/conv2d_params ( type:  Const )
# 280/993: Analysing op name: mixed_4/join/concat_dim ( type:  Const )
# 281/993: Analysing op name: mixed_4/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 282/993: Analysing op name: mixed_4/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 283/993: Analysing op name: mixed_4/tower_2/conv/batchnorm/gamma ( type:  Const )
# 284/993: Analysing op name: mixed_4/tower_2/conv/batchnorm/beta ( type:  Const )
# 285/993: Analysing op name: mixed_4/tower_2/conv/conv2d_params ( type:  Const )
# 286/993: Analysing op name: mixed_4/tower_1/conv_4/batchnorm/moving_variance ( type:  Const )
# 287/993: Analysing op name: mixed_4/tower_1/conv_4/batchnorm/moving_mean ( type:  Const )
# 288/993: Analysing op name: mixed_4/tower_1/conv_4/batchnorm/gamma ( type:  Const )
# 289/993: Analysing op name: mixed_4/tower_1/conv_4/batchnorm/beta ( type:  Const )
# 290/993: Analysing op name: mixed_4/tower_1/conv_4/conv2d_params ( type:  Const )
# 291/993: Analysing op name: mixed_4/tower_1/conv_3/batchnorm/moving_variance ( type:  Const )
# 292/993: Analysing op name: mixed_4/tower_1/conv_3/batchnorm/moving_mean ( type:  Const )
# 293/993: Analysing op name: mixed_4/tower_1/conv_3/batchnorm/gamma ( type:  Const )
# 294/993: Analysing op name: mixed_4/tower_1/conv_3/batchnorm/beta ( type:  Const )
# 295/993: Analysing op name: mixed_4/tower_1/conv_3/conv2d_params ( type:  Const )
# 296/993: Analysing op name: mixed_4/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 297/993: Analysing op name: mixed_4/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 298/993: Analysing op name: mixed_4/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 299/993: Analysing op name: mixed_4/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 300/993: Analysing op name: mixed_4/tower_1/conv_2/conv2d_params ( type:  Const )
# 301/993: Analysing op name: mixed_4/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 302/993: Analysing op name: mixed_4/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 303/993: Analysing op name: mixed_4/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 304/993: Analysing op name: mixed_4/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 305/993: Analysing op name: mixed_4/tower_1/conv_1/conv2d_params ( type:  Const )
# 306/993: Analysing op name: mixed_4/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 307/993: Analysing op name: mixed_4/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 308/993: Analysing op name: mixed_4/tower_1/conv/batchnorm/gamma ( type:  Const )
# 309/993: Analysing op name: mixed_4/tower_1/conv/batchnorm/beta ( type:  Const )
# 310/993: Analysing op name: mixed_4/tower_1/conv/conv2d_params ( type:  Const )
# 311/993: Analysing op name: mixed_4/tower/conv_2/batchnorm/moving_variance ( type:  Const )
# 312/993: Analysing op name: mixed_4/tower/conv_2/batchnorm/moving_mean ( type:  Const )
# 313/993: Analysing op name: mixed_4/tower/conv_2/batchnorm/gamma ( type:  Const )
# 314/993: Analysing op name: mixed_4/tower/conv_2/batchnorm/beta ( type:  Const )
# 315/993: Analysing op name: mixed_4/tower/conv_2/conv2d_params ( type:  Const )
# 316/993: Analysing op name: mixed_4/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 317/993: Analysing op name: mixed_4/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 318/993: Analysing op name: mixed_4/tower/conv_1/batchnorm/gamma ( type:  Const )
# 319/993: Analysing op name: mixed_4/tower/conv_1/batchnorm/beta ( type:  Const )
# 320/993: Analysing op name: mixed_4/tower/conv_1/conv2d_params ( type:  Const )
# 321/993: Analysing op name: mixed_4/tower/conv/batchnorm/moving_variance ( type:  Const )
# 322/993: Analysing op name: mixed_4/tower/conv/batchnorm/moving_mean ( type:  Const )
# 323/993: Analysing op name: mixed_4/tower/conv/batchnorm/gamma ( type:  Const )
# 324/993: Analysing op name: mixed_4/tower/conv/batchnorm/beta ( type:  Const )
# 325/993: Analysing op name: mixed_4/tower/conv/conv2d_params ( type:  Const )
# 326/993: Analysing op name: mixed_4/conv/batchnorm/moving_variance ( type:  Const )
# 327/993: Analysing op name: mixed_4/conv/batchnorm/moving_mean ( type:  Const )
# 328/993: Analysing op name: mixed_4/conv/batchnorm/gamma ( type:  Const )
# 329/993: Analysing op name: mixed_4/conv/batchnorm/beta ( type:  Const )
# 330/993: Analysing op name: mixed_4/conv/conv2d_params ( type:  Const )
# 331/993: Analysing op name: mixed_3/join/concat_dim ( type:  Const )
# 332/993: Analysing op name: mixed_3/tower/conv_2/batchnorm/moving_variance ( type:  Const )
# 333/993: Analysing op name: mixed_3/tower/conv_2/batchnorm/moving_mean ( type:  Const )
# 334/993: Analysing op name: mixed_3/tower/conv_2/batchnorm/gamma ( type:  Const )
# 335/993: Analysing op name: mixed_3/tower/conv_2/batchnorm/beta ( type:  Const )
# 336/993: Analysing op name: mixed_3/tower/conv_2/conv2d_params ( type:  Const )
# 337/993: Analysing op name: mixed_3/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 338/993: Analysing op name: mixed_3/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 339/993: Analysing op name: mixed_3/tower/conv_1/batchnorm/gamma ( type:  Const )
# 340/993: Analysing op name: mixed_3/tower/conv_1/batchnorm/beta ( type:  Const )
# 341/993: Analysing op name: mixed_3/tower/conv_1/conv2d_params ( type:  Const )
# 342/993: Analysing op name: mixed_3/tower/conv/batchnorm/moving_variance ( type:  Const )
# 343/993: Analysing op name: mixed_3/tower/conv/batchnorm/moving_mean ( type:  Const )
# 344/993: Analysing op name: mixed_3/tower/conv/batchnorm/gamma ( type:  Const )
# 345/993: Analysing op name: mixed_3/tower/conv/batchnorm/beta ( type:  Const )
# 346/993: Analysing op name: mixed_3/tower/conv/conv2d_params ( type:  Const )
# 347/993: Analysing op name: mixed_3/conv/batchnorm/moving_variance ( type:  Const )
# 348/993: Analysing op name: mixed_3/conv/batchnorm/moving_mean ( type:  Const )
# 349/993: Analysing op name: mixed_3/conv/batchnorm/gamma ( type:  Const )
# 350/993: Analysing op name: mixed_3/conv/batchnorm/beta ( type:  Const )
# 351/993: Analysing op name: mixed_3/conv/conv2d_params ( type:  Const )
# 352/993: Analysing op name: mixed_2/join/concat_dim ( type:  Const )
# 353/993: Analysing op name: mixed_2/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 354/993: Analysing op name: mixed_2/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 355/993: Analysing op name: mixed_2/tower_2/conv/batchnorm/gamma ( type:  Const )
# 356/993: Analysing op name: mixed_2/tower_2/conv/batchnorm/beta ( type:  Const )
# 357/993: Analysing op name: mixed_2/tower_2/conv/conv2d_params ( type:  Const )
# 358/993: Analysing op name: mixed_2/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 359/993: Analysing op name: mixed_2/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 360/993: Analysing op name: mixed_2/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 361/993: Analysing op name: mixed_2/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 362/993: Analysing op name: mixed_2/tower_1/conv_2/conv2d_params ( type:  Const )
# 363/993: Analysing op name: mixed_2/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 364/993: Analysing op name: mixed_2/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 365/993: Analysing op name: mixed_2/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 366/993: Analysing op name: mixed_2/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 367/993: Analysing op name: mixed_2/tower_1/conv_1/conv2d_params ( type:  Const )
# 368/993: Analysing op name: mixed_2/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 369/993: Analysing op name: mixed_2/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 370/993: Analysing op name: mixed_2/tower_1/conv/batchnorm/gamma ( type:  Const )
# 371/993: Analysing op name: mixed_2/tower_1/conv/batchnorm/beta ( type:  Const )
# 372/993: Analysing op name: mixed_2/tower_1/conv/conv2d_params ( type:  Const )
# 373/993: Analysing op name: mixed_2/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 374/993: Analysing op name: mixed_2/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 375/993: Analysing op name: mixed_2/tower/conv_1/batchnorm/gamma ( type:  Const )
# 376/993: Analysing op name: mixed_2/tower/conv_1/batchnorm/beta ( type:  Const )
# 377/993: Analysing op name: mixed_2/tower/conv_1/conv2d_params ( type:  Const )
# 378/993: Analysing op name: mixed_2/tower/conv/batchnorm/moving_variance ( type:  Const )
# 379/993: Analysing op name: mixed_2/tower/conv/batchnorm/moving_mean ( type:  Const )
# 380/993: Analysing op name: mixed_2/tower/conv/batchnorm/gamma ( type:  Const )
# 381/993: Analysing op name: mixed_2/tower/conv/batchnorm/beta ( type:  Const )
# 382/993: Analysing op name: mixed_2/tower/conv/conv2d_params ( type:  Const )
# 383/993: Analysing op name: mixed_2/conv/batchnorm/moving_variance ( type:  Const )
# 384/993: Analysing op name: mixed_2/conv/batchnorm/moving_mean ( type:  Const )
# 385/993: Analysing op name: mixed_2/conv/batchnorm/gamma ( type:  Const )
# 386/993: Analysing op name: mixed_2/conv/batchnorm/beta ( type:  Const )
# 387/993: Analysing op name: mixed_2/conv/conv2d_params ( type:  Const )
# 388/993: Analysing op name: mixed_1/join/concat_dim ( type:  Const )
# 389/993: Analysing op name: mixed_1/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 390/993: Analysing op name: mixed_1/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 391/993: Analysing op name: mixed_1/tower_2/conv/batchnorm/gamma ( type:  Const )
# 392/993: Analysing op name: mixed_1/tower_2/conv/batchnorm/beta ( type:  Const )
# 393/993: Analysing op name: mixed_1/tower_2/conv/conv2d_params ( type:  Const )
# 394/993: Analysing op name: mixed_1/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 395/993: Analysing op name: mixed_1/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 396/993: Analysing op name: mixed_1/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 397/993: Analysing op name: mixed_1/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 398/993: Analysing op name: mixed_1/tower_1/conv_2/conv2d_params ( type:  Const )
# 399/993: Analysing op name: mixed_1/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 400/993: Analysing op name: mixed_1/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 401/993: Analysing op name: mixed_1/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 402/993: Analysing op name: mixed_1/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 403/993: Analysing op name: mixed_1/tower_1/conv_1/conv2d_params ( type:  Const )
# 404/993: Analysing op name: mixed_1/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 405/993: Analysing op name: mixed_1/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 406/993: Analysing op name: mixed_1/tower_1/conv/batchnorm/gamma ( type:  Const )
# 407/993: Analysing op name: mixed_1/tower_1/conv/batchnorm/beta ( type:  Const )
# 408/993: Analysing op name: mixed_1/tower_1/conv/conv2d_params ( type:  Const )
# 409/993: Analysing op name: mixed_1/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 410/993: Analysing op name: mixed_1/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 411/993: Analysing op name: mixed_1/tower/conv_1/batchnorm/gamma ( type:  Const )
# 412/993: Analysing op name: mixed_1/tower/conv_1/batchnorm/beta ( type:  Const )
# 413/993: Analysing op name: mixed_1/tower/conv_1/conv2d_params ( type:  Const )
# 414/993: Analysing op name: mixed_1/tower/conv/batchnorm/moving_variance ( type:  Const )
# 415/993: Analysing op name: mixed_1/tower/conv/batchnorm/moving_mean ( type:  Const )
# 416/993: Analysing op name: mixed_1/tower/conv/batchnorm/gamma ( type:  Const )
# 417/993: Analysing op name: mixed_1/tower/conv/batchnorm/beta ( type:  Const )
# 418/993: Analysing op name: mixed_1/tower/conv/conv2d_params ( type:  Const )
# 419/993: Analysing op name: mixed_1/conv/batchnorm/moving_variance ( type:  Const )
# 420/993: Analysing op name: mixed_1/conv/batchnorm/moving_mean ( type:  Const )
# 421/993: Analysing op name: mixed_1/conv/batchnorm/gamma ( type:  Const )
# 422/993: Analysing op name: mixed_1/conv/batchnorm/beta ( type:  Const )
# 423/993: Analysing op name: mixed_1/conv/conv2d_params ( type:  Const )
# 424/993: Analysing op name: mixed/join/concat_dim ( type:  Const )
# 425/993: Analysing op name: mixed/tower_2/conv/batchnorm/moving_variance ( type:  Const )
# 426/993: Analysing op name: mixed/tower_2/conv/batchnorm/moving_mean ( type:  Const )
# 427/993: Analysing op name: mixed/tower_2/conv/batchnorm/gamma ( type:  Const )
# 428/993: Analysing op name: mixed/tower_2/conv/batchnorm/beta ( type:  Const )
# 429/993: Analysing op name: mixed/tower_2/conv/conv2d_params ( type:  Const )
# 430/993: Analysing op name: mixed/tower_1/conv_2/batchnorm/moving_variance ( type:  Const )
# 431/993: Analysing op name: mixed/tower_1/conv_2/batchnorm/moving_mean ( type:  Const )
# 432/993: Analysing op name: mixed/tower_1/conv_2/batchnorm/gamma ( type:  Const )
# 433/993: Analysing op name: mixed/tower_1/conv_2/batchnorm/beta ( type:  Const )
# 434/993: Analysing op name: mixed/tower_1/conv_2/conv2d_params ( type:  Const )
# 435/993: Analysing op name: mixed/tower_1/conv_1/batchnorm/moving_variance ( type:  Const )
# 436/993: Analysing op name: mixed/tower_1/conv_1/batchnorm/moving_mean ( type:  Const )
# 437/993: Analysing op name: mixed/tower_1/conv_1/batchnorm/gamma ( type:  Const )
# 438/993: Analysing op name: mixed/tower_1/conv_1/batchnorm/beta ( type:  Const )
# 439/993: Analysing op name: mixed/tower_1/conv_1/conv2d_params ( type:  Const )
# 440/993: Analysing op name: mixed/tower_1/conv/batchnorm/moving_variance ( type:  Const )
# 441/993: Analysing op name: mixed/tower_1/conv/batchnorm/moving_mean ( type:  Const )
# 442/993: Analysing op name: mixed/tower_1/conv/batchnorm/gamma ( type:  Const )
# 443/993: Analysing op name: mixed/tower_1/conv/batchnorm/beta ( type:  Const )
# 444/993: Analysing op name: mixed/tower_1/conv/conv2d_params ( type:  Const )
# 445/993: Analysing op name: mixed/tower/conv_1/batchnorm/moving_variance ( type:  Const )
# 446/993: Analysing op name: mixed/tower/conv_1/batchnorm/moving_mean ( type:  Const )
# 447/993: Analysing op name: mixed/tower/conv_1/batchnorm/gamma ( type:  Const )
# 448/993: Analysing op name: mixed/tower/conv_1/batchnorm/beta ( type:  Const )
# 449/993: Analysing op name: mixed/tower/conv_1/conv2d_params ( type:  Const )
# 450/993: Analysing op name: mixed/tower/conv/batchnorm/moving_variance ( type:  Const )
# 451/993: Analysing op name: mixed/tower/conv/batchnorm/moving_mean ( type:  Const )
# 452/993: Analysing op name: mixed/tower/conv/batchnorm/gamma ( type:  Const )
# 453/993: Analysing op name: mixed/tower/conv/batchnorm/beta ( type:  Const )
# 454/993: Analysing op name: mixed/tower/conv/conv2d_params ( type:  Const )
# 455/993: Analysing op name: mixed/conv/batchnorm/moving_variance ( type:  Const )
# 456/993: Analysing op name: mixed/conv/batchnorm/moving_mean ( type:  Const )
# 457/993: Analysing op name: mixed/conv/batchnorm/gamma ( type:  Const )
# 458/993: Analysing op name: mixed/conv/batchnorm/beta ( type:  Const )
# 459/993: Analysing op name: mixed/conv/conv2d_params ( type:  Const )
# 460/993: Analysing op name: conv_4/batchnorm/moving_variance ( type:  Const )
# 461/993: Analysing op name: conv_4/batchnorm/moving_mean ( type:  Const )
# 462/993: Analysing op name: conv_4/batchnorm/gamma ( type:  Const )
# 463/993: Analysing op name: conv_4/batchnorm/beta ( type:  Const )
# 464/993: Analysing op name: conv_4/conv2d_params ( type:  Const )
# 465/993: Analysing op name: conv_3/batchnorm/moving_variance ( type:  Const )
# 466/993: Analysing op name: conv_3/batchnorm/moving_mean ( type:  Const )
# 467/993: Analysing op name: conv_3/batchnorm/gamma ( type:  Const )
# 468/993: Analysing op name: conv_3/batchnorm/beta ( type:  Const )
# 469/993: Analysing op name: conv_3/conv2d_params ( type:  Const )
# 470/993: Analysing op name: conv_2/batchnorm/moving_variance ( type:  Const )
# 471/993: Analysing op name: conv_2/batchnorm/moving_mean ( type:  Const )
# 472/993: Analysing op name: conv_2/batchnorm/gamma ( type:  Const )
# 473/993: Analysing op name: conv_2/batchnorm/beta ( type:  Const )
# 474/993: Analysing op name: conv_2/conv2d_params ( type:  Const )
# 475/993: Analysing op name: conv_1/batchnorm/moving_variance ( type:  Const )
# 476/993: Analysing op name: conv_1/batchnorm/moving_mean ( type:  Const )
# 477/993: Analysing op name: conv_1/batchnorm/gamma ( type:  Const )
# 478/993: Analysing op name: conv_1/batchnorm/beta ( type:  Const )
# 479/993: Analysing op name: conv_1/conv2d_params ( type:  Const )
# 480/993: Analysing op name: conv/batchnorm/moving_variance ( type:  Const )
# 481/993: Analysing op name: conv/batchnorm/moving_mean ( type:  Const )
# 482/993: Analysing op name: conv/batchnorm/gamma ( type:  Const )
# 483/993: Analysing op name: conv/batchnorm/beta ( type:  Const )
# 484/993: Analysing op name: conv/conv2d_params ( type:  Const )
# 485/993: Analysing op name: Mul ( type:  Placeholder )
# Skipping name of placeholder
# 486/993: Analysing op name: conv/Conv2D ( type:  Conv2D )
# 487/993: Analysing op name: conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 488/993: Analysing op name: conv/control_dependency ( type:  Identity )
# 489/993: Analysing op name: conv ( type:  Relu )
# 490/993: Analysing op name: conv_1/Conv2D ( type:  Conv2D )
# 491/993: Analysing op name: conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 492/993: Analysing op name: conv_1/control_dependency ( type:  Identity )
# 493/993: Analysing op name: conv_1 ( type:  Relu )
# 494/993: Analysing op name: conv_2/Conv2D ( type:  Conv2D )
# 495/993: Analysing op name: conv_2/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 496/993: Analysing op name: conv_2/control_dependency ( type:  Identity )
# 497/993: Analysing op name: conv_2 ( type:  Relu )
# 498/993: Analysing op name: pool/control_dependency ( type:  Identity )
# 499/993: Analysing op name: pool ( type:  MaxPool )
# 500/993: Analysing op name: conv_3/Conv2D ( type:  Conv2D )
# 501/993: Analysing op name: conv_3/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 502/993: Analysing op name: conv_3/control_dependency ( type:  Identity )
# 503/993: Analysing op name: conv_3 ( type:  Relu )
# 504/993: Analysing op name: conv_4/Conv2D ( type:  Conv2D )
# 505/993: Analysing op name: conv_4/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 506/993: Analysing op name: conv_4/control_dependency ( type:  Identity )
# 507/993: Analysing op name: conv_4 ( type:  Relu )
# 508/993: Analysing op name: pool_1/control_dependency ( type:  Identity )
# 509/993: Analysing op name: pool_1 ( type:  MaxPool )
# 510/993: Analysing op name: mixed/tower_2/pool ( type:  AvgPool )
# 511/993: Analysing op name: mixed/tower_2/conv/Conv2D ( type:  Conv2D )
# 512/993: Analysing op name: mixed/tower_2/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 513/993: Analysing op name: mixed/tower_2/conv/control_dependency ( type:  Identity )
# 514/993: Analysing op name: mixed/tower_2/conv ( type:  Relu )
# 515/993: Analysing op name: mixed/tower_2/conv/CheckNumerics ( type:  CheckNumerics )
# 516/993: Analysing op name: mixed/tower_1/conv/Conv2D ( type:  Conv2D )
# 517/993: Analysing op name: mixed/tower_1/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 518/993: Analysing op name: mixed/tower_1/conv/control_dependency ( type:  Identity )
# 519/993: Analysing op name: mixed/tower_1/conv ( type:  Relu )
# 520/993: Analysing op name: mixed/tower_1/conv_1/Conv2D ( type:  Conv2D )
# 521/993: Analysing op name: mixed/tower_1/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 522/993: Analysing op name: mixed/tower_1/conv_1/control_dependency ( type:  Identity )
# 523/993: Analysing op name: mixed/tower_1/conv_1 ( type:  Relu )
# 524/993: Analysing op name: mixed/tower_1/conv_2/Conv2D ( type:  Conv2D )
# 525/993: Analysing op name: mixed/tower_1/conv_2/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 526/993: Analysing op name: mixed/tower_1/conv_2/control_dependency ( type:  Identity )
# 527/993: Analysing op name: mixed/tower_1/conv_2 ( type:  Relu )
# 528/993: Analysing op name: mixed/tower_1/conv_2/CheckNumerics ( type:  CheckNumerics )
# 529/993: Analysing op name: mixed/tower_1/conv_1/CheckNumerics ( type:  CheckNumerics )
# 530/993: Analysing op name: mixed/tower_1/conv/CheckNumerics ( type:  CheckNumerics )
# 531/993: Analysing op name: mixed/tower/conv/Conv2D ( type:  Conv2D )
# 532/993: Analysing op name: mixed/tower/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 533/993: Analysing op name: mixed/tower/conv/control_dependency ( type:  Identity )
# 534/993: Analysing op name: mixed/tower/conv ( type:  Relu )
# 535/993: Analysing op name: mixed/tower/conv_1/Conv2D ( type:  Conv2D )
# 536/993: Analysing op name: mixed/tower/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 537/993: Analysing op name: mixed/tower/conv_1/control_dependency ( type:  Identity )
# 538/993: Analysing op name: mixed/tower/conv_1 ( type:  Relu )
# 539/993: Analysing op name: mixed/tower/conv_1/CheckNumerics ( type:  CheckNumerics )
# 540/993: Analysing op name: mixed/tower/conv/CheckNumerics ( type:  CheckNumerics )
# 541/993: Analysing op name: mixed/conv/Conv2D ( type:  Conv2D )
# 542/993: Analysing op name: mixed/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 543/993: Analysing op name: mixed/conv/control_dependency ( type:  Identity )
# 544/993: Analysing op name: mixed/conv ( type:  Relu )
# 545/993: Analysing op name: mixed/join ( type:  Concat )
# 546/993: Analysing op name: mixed_1/tower_2/pool ( type:  AvgPool )
# 547/993: Analysing op name: mixed_1/tower_2/conv/Conv2D ( type:  Conv2D )
# 548/993: Analysing op name: mixed_1/tower_2/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 549/993: Analysing op name: mixed_1/tower_2/conv/control_dependency ( type:  Identity )
# 550/993: Analysing op name: mixed_1/tower_2/conv ( type:  Relu )
# 551/993: Analysing op name: mixed_1/tower_2/conv/CheckNumerics ( type:  CheckNumerics )
# 552/993: Analysing op name: mixed_1/tower_1/conv/Conv2D ( type:  Conv2D )
# 553/993: Analysing op name: mixed_1/tower_1/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 554/993: Analysing op name: mixed_1/tower_1/conv/control_dependency ( type:  Identity )
# 555/993: Analysing op name: mixed_1/tower_1/conv ( type:  Relu )
# 556/993: Analysing op name: mixed_1/tower_1/conv_1/Conv2D ( type:  Conv2D )
# 557/993: Analysing op name: mixed_1/tower_1/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 558/993: Analysing op name: mixed_1/tower_1/conv_1/control_dependency ( type:  Identity )
# 559/993: Analysing op name: mixed_1/tower_1/conv_1 ( type:  Relu )
# 560/993: Analysing op name: mixed_1/tower_1/conv_2/Conv2D ( type:  Conv2D )
# 561/993: Analysing op name: mixed_1/tower_1/conv_2/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 562/993: Analysing op name: mixed_1/tower_1/conv_2/control_dependency ( type:  Identity )
# 563/993: Analysing op name: mixed_1/tower_1/conv_2 ( type:  Relu )
# 564/993: Analysing op name: mixed_1/tower_1/conv_2/CheckNumerics ( type:  CheckNumerics )
# 565/993: Analysing op name: mixed_1/tower_1/conv_1/CheckNumerics ( type:  CheckNumerics )
# 566/993: Analysing op name: mixed_1/tower_1/conv/CheckNumerics ( type:  CheckNumerics )
# 567/993: Analysing op name: mixed_1/tower/conv/Conv2D ( type:  Conv2D )
# 568/993: Analysing op name: mixed_1/tower/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 569/993: Analysing op name: mixed_1/tower/conv/control_dependency ( type:  Identity )
# 570/993: Analysing op name: mixed_1/tower/conv ( type:  Relu )
# 571/993: Analysing op name: mixed_1/tower/conv_1/Conv2D ( type:  Conv2D )
# 572/993: Analysing op name: mixed_1/tower/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 573/993: Analysing op name: mixed_1/tower/conv_1/control_dependency ( type:  Identity )
# ...
# 788/993: Analysing op name: mixed_6/tower/conv/CheckNumerics ( type:  CheckNumerics )
# 789/993: Analysing op name: mixed_6/conv/Conv2D ( type:  Conv2D )
# 790/993: Analysing op name: mixed_6/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 791/993: Analysing op name: mixed_6/conv/control_dependency ( type:  Identity )
# 792/993: Analysing op name: mixed_6/conv ( type:  Relu )
# 793/993: Analysing op name: mixed_6/join ( type:  Concat )
# 794/993: Analysing op name: mixed_7/tower_2/pool ( type:  AvgPool )
# 795/993: Analysing op name: mixed_7/tower_2/conv/Conv2D ( type:  Conv2D )
# 796/993: Analysing op name: mixed_7/tower_2/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 797/993: Analysing op name: mixed_7/tower_2/conv/control_dependency ( type:  Identity )
# 798/993: Analysing op name: mixed_7/tower_2/conv ( type:  Relu )
# 799/993: Analysing op name: mixed_7/tower_2/conv/CheckNumerics ( type:  CheckNumerics )
# 800/993: Analysing op name: mixed_7/tower_1/conv/Conv2D ( type:  Conv2D )
# 801/993: Analysing op name: mixed_7/tower_1/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 802/993: Analysing op name: mixed_7/tower_1/conv/control_dependency ( type:  Identity )
# 803/993: Analysing op name: mixed_7/tower_1/conv ( type:  Relu )
# 804/993: Analysing op name: mixed_7/tower_1/conv_1/Conv2D ( type:  Conv2D )
# 805/993: Analysing op name: mixed_7/tower_1/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 806/993: Analysing op name: mixed_7/tower_1/conv_1/control_dependency ( type:  Identity )
# 807/993: Analysing op name: mixed_7/tower_1/conv_1 ( type:  Relu )
# 808/993: Analysing op name: mixed_7/tower_1/conv_2/Conv2D ( type:  Conv2D )
# 809/993: Analysing op name: mixed_7/tower_1/conv_2/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 810/993: Analysing op name: mixed_7/tower_1/conv_2/control_dependency ( type:  Identity )
# 811/993: Analysing op name: mixed_7/tower_1/conv_2 ( type:  Relu )
# 812/993: Analysing op name: mixed_7/tower_1/conv_3/Conv2D ( type:  Conv2D )
# 813/993: Analysing op name: mixed_7/tower_1/conv_3/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 814/993: Analysing op name: mixed_7/tower_1/conv_3/control_dependency ( type:  Identity )
# 815/993: Analysing op name: mixed_7/tower_1/conv_3 ( type:  Relu )
# 816/993: Analysing op name: mixed_7/tower_1/conv_4/Conv2D ( type:  Conv2D )
# 817/993: Analysing op name: mixed_7/tower_1/conv_4/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 818/993: Analysing op name: mixed_7/tower_1/conv_4/control_dependency ( type:  Identity )
# 819/993: Analysing op name: mixed_7/tower_1/conv_4 ( type:  Relu )
# 820/993: Analysing op name: mixed_7/tower_1/conv_4/CheckNumerics ( type:  CheckNumerics )
# 821/993: Analysing op name: mixed_7/tower_1/conv_3/CheckNumerics ( type:  CheckNumerics )
# 822/993: Analysing op name: mixed_7/tower_1/conv_2/CheckNumerics ( type:  CheckNumerics )
# 823/993: Analysing op name: mixed_7/tower_1/conv_1/CheckNumerics ( type:  CheckNumerics )
# 824/993: Analysing op name: mixed_7/tower_1/conv/CheckNumerics ( type:  CheckNumerics )
# 825/993: Analysing op name: mixed_7/tower/conv/Conv2D ( type:  Conv2D )
# 826/993: Analysing op name: mixed_7/tower/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 827/993: Analysing op name: mixed_7/tower/conv/control_dependency ( type:  Identity )
# 828/993: Analysing op name: mixed_7/tower/conv ( type:  Relu )
# 829/993: Analysing op name: mixed_7/tower/conv_1/Conv2D ( type:  Conv2D )
# 830/993: Analysing op name: mixed_7/tower/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 831/993: Analysing op name: mixed_7/tower/conv_1/control_dependency ( type:  Identity )
# 832/993: Analysing op name: mixed_7/tower/conv_1 ( type:  Relu )
# 833/993: Analysing op name: mixed_7/tower/conv_2/Conv2D ( type:  Conv2D )
# 834/993: Analysing op name: mixed_7/tower/conv_2/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 835/993: Analysing op name: mixed_7/tower/conv_2/control_dependency ( type:  Identity )
# 836/993: Analysing op name: mixed_7/tower/conv_2 ( type:  Relu )
# 837/993: Analysing op name: mixed_7/tower/conv_2/CheckNumerics ( type:  CheckNumerics )
# 838/993: Analysing op name: mixed_7/tower/conv_1/CheckNumerics ( type:  CheckNumerics )
# 839/993: Analysing op name: mixed_7/tower/conv/CheckNumerics ( type:  CheckNumerics )
# 840/993: Analysing op name: mixed_7/conv/Conv2D ( type:  Conv2D )
# 841/993: Analysing op name: mixed_7/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 842/993: Analysing op name: mixed_7/conv/control_dependency ( type:  Identity )
# 843/993: Analysing op name: mixed_7/conv ( type:  Relu )
# 844/993: Analysing op name: mixed_7/join ( type:  Concat )
# 845/993: Analysing op name: mixed_8/pool/control_dependency ( type:  Identity )
# 846/993: Analysing op name: mixed_8/pool ( type:  MaxPool )
# 847/993: Analysing op name: mixed_8/pool/CheckNumerics ( type:  CheckNumerics )
# 848/993: Analysing op name: mixed_8/tower_1/conv/Conv2D ( type:  Conv2D )
# 849/993: Analysing op name: mixed_8/tower_1/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 850/993: Analysing op name: mixed_8/tower_1/conv/control_dependency ( type:  Identity )
# 851/993: Analysing op name: mixed_8/tower_1/conv ( type:  Relu )
# 852/993: Analysing op name: mixed_8/tower_1/conv_1/Conv2D ( type:  Conv2D )
# 853/993: Analysing op name: mixed_8/tower_1/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 854/993: Analysing op name: mixed_8/tower_1/conv_1/control_dependency ( type:  Identity )
# 855/993: Analysing op name: mixed_8/tower_1/conv_1 ( type:  Relu )
# 856/993: Analysing op name: mixed_8/tower_1/conv_2/Conv2D ( type:  Conv2D )
# 857/993: Analysing op name: mixed_8/tower_1/conv_2/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 858/993: Analysing op name: mixed_8/tower_1/conv_2/control_dependency ( type:  Identity )
# 859/993: Analysing op name: mixed_8/tower_1/conv_2 ( type:  Relu )
# 860/993: Analysing op name: mixed_8/tower_1/conv_3/Conv2D ( type:  Conv2D )
# 861/993: Analysing op name: mixed_8/tower_1/conv_3/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 862/993: Analysing op name: mixed_8/tower_1/conv_3/control_dependency ( type:  Identity )
# 863/993: Analysing op name: mixed_8/tower_1/conv_3 ( type:  Relu )
# 864/993: Analysing op name: mixed_8/tower_1/conv_3/CheckNumerics ( type:  CheckNumerics )
# 865/993: Analysing op name: mixed_8/tower_1/conv_2/CheckNumerics ( type:  CheckNumerics )
# 866/993: Analysing op name: mixed_8/tower_1/conv_1/CheckNumerics ( type:  CheckNumerics )
# 867/993: Analysing op name: mixed_8/tower_1/conv/CheckNumerics ( type:  CheckNumerics )
# 868/993: Analysing op name: mixed_8/tower/conv/Conv2D ( type:  Conv2D )
# 869/993: Analysing op name: mixed_8/tower/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 870/993: Analysing op name: mixed_8/tower/conv/control_dependency ( type:  Identity )
# 871/993: Analysing op name: mixed_8/tower/conv ( type:  Relu )
# 872/993: Analysing op name: mixed_8/tower/conv_1/Conv2D ( type:  Conv2D )
# 873/993: Analysing op name: mixed_8/tower/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 874/993: Analysing op name: mixed_8/tower/conv_1/control_dependency ( type:  Identity )
# 875/993: Analysing op name: mixed_8/tower/conv_1 ( type:  Relu )
# 876/993: Analysing op name: mixed_8/join ( type:  Concat )
# 877/993: Analysing op name: mixed_9/tower_2/pool ( type:  AvgPool )
# 878/993: Analysing op name: mixed_9/tower_2/conv/Conv2D ( type:  Conv2D )
# 879/993: Analysing op name: mixed_9/tower_2/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 880/993: Analysing op name: mixed_9/tower_2/conv/control_dependency ( type:  Identity )
# 881/993: Analysing op name: mixed_9/tower_2/conv ( type:  Relu )
# 882/993: Analysing op name: mixed_9/tower_2/conv/CheckNumerics ( type:  CheckNumerics )
# 883/993: Analysing op name: mixed_9/tower_1/conv/Conv2D ( type:  Conv2D )
# 884/993: Analysing op name: mixed_9/tower_1/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 885/993: Analysing op name: mixed_9/tower_1/conv/control_dependency ( type:  Identity )
# 886/993: Analysing op name: mixed_9/tower_1/conv ( type:  Relu )
# 887/993: Analysing op name: mixed_9/tower_1/conv_1/Conv2D ( type:  Conv2D )
# 888/993: Analysing op name: mixed_9/tower_1/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 889/993: Analysing op name: mixed_9/tower_1/conv_1/control_dependency ( type:  Identity )
# 890/993: Analysing op name: mixed_9/tower_1/conv_1 ( type:  Relu )
# 891/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/Conv2D ( type:  Conv2D )
# 892/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 893/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/control_dependency ( type:  Identity )
# 894/993: Analysing op name: mixed_9/tower_1/mixed/conv_1 ( type:  Relu )
# 895/993: Analysing op name: mixed_9/tower_1/mixed/conv_1/CheckNumerics ( type:  CheckNumerics )
# 896/993: Analysing op name: mixed_9/tower_1/mixed/conv/Conv2D ( type:  Conv2D )
# 897/993: Analysing op name: mixed_9/tower_1/mixed/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 898/993: Analysing op name: mixed_9/tower_1/mixed/conv/control_dependency ( type:  Identity )
# 899/993: Analysing op name: mixed_9/tower_1/mixed/conv ( type:  Relu )
# 900/993: Analysing op name: mixed_9/tower_1/mixed/conv/CheckNumerics ( type:  CheckNumerics )
# 901/993: Analysing op name: mixed_9/tower_1/conv_1/CheckNumerics ( type:  CheckNumerics )
# 902/993: Analysing op name: mixed_9/tower_1/conv/CheckNumerics ( type:  CheckNumerics )
# 903/993: Analysing op name: mixed_9/tower/conv/Conv2D ( type:  Conv2D )
# 904/993: Analysing op name: mixed_9/tower/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 905/993: Analysing op name: mixed_9/tower/conv/control_dependency ( type:  Identity )
# 906/993: Analysing op name: mixed_9/tower/conv ( type:  Relu )
# 907/993: Analysing op name: mixed_9/tower/mixed/conv_1/Conv2D ( type:  Conv2D )
# 908/993: Analysing op name: mixed_9/tower/mixed/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 909/993: Analysing op name: mixed_9/tower/mixed/conv_1/control_dependency ( type:  Identity )
# 910/993: Analysing op name: mixed_9/tower/mixed/conv_1 ( type:  Relu )
# 911/993: Analysing op name: mixed_9/tower/mixed/conv_1/CheckNumerics ( type:  CheckNumerics )
# 912/993: Analysing op name: mixed_9/tower/mixed/conv/Conv2D ( type:  Conv2D )
# 913/993: Analysing op name: mixed_9/tower/mixed/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 914/993: Analysing op name: mixed_9/tower/mixed/conv/control_dependency ( type:  Identity )
# 915/993: Analysing op name: mixed_9/tower/mixed/conv ( type:  Relu )
# 916/993: Analysing op name: mixed_9/tower/mixed/conv/CheckNumerics ( type:  CheckNumerics )
# 917/993: Analysing op name: mixed_9/tower/conv/CheckNumerics ( type:  CheckNumerics )
# 918/993: Analysing op name: mixed_9/conv/Conv2D ( type:  Conv2D )
# 919/993: Analysing op name: mixed_9/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 920/993: Analysing op name: mixed_9/conv/control_dependency ( type:  Identity )
# 921/993: Analysing op name: mixed_9/conv ( type:  Relu )
# 922/993: Analysing op name: mixed_9/join ( type:  Concat )
# 923/993: Analysing op name: mixed_10/tower_2/pool/control_dependency ( type:  Identity )
# 924/993: Analysing op name: mixed_10/tower_2/pool ( type:  MaxPool )
# 925/993: Analysing op name: mixed_10/tower_2/conv/Conv2D ( type:  Conv2D )
# 926/993: Analysing op name: mixed_10/tower_2/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 927/993: Analysing op name: mixed_10/tower_2/conv/control_dependency ( type:  Identity )
# 928/993: Analysing op name: mixed_10/tower_2/conv ( type:  Relu )
# 929/993: Analysing op name: mixed_10/tower_2/conv/CheckNumerics ( type:  CheckNumerics )
# 930/993: Analysing op name: mixed_10/tower_2/pool/CheckNumerics ( type:  CheckNumerics )
# 931/993: Analysing op name: mixed_10/tower_1/conv/Conv2D ( type:  Conv2D )
# 932/993: Analysing op name: mixed_10/tower_1/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 933/993: Analysing op name: mixed_10/tower_1/conv/control_dependency ( type:  Identity )
# 934/993: Analysing op name: mixed_10/tower_1/conv ( type:  Relu )
# 935/993: Analysing op name: mixed_10/tower_1/conv_1/Conv2D ( type:  Conv2D )
# 936/993: Analysing op name: mixed_10/tower_1/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 937/993: Analysing op name: mixed_10/tower_1/conv_1/control_dependency ( type:  Identity )
# 938/993: Analysing op name: mixed_10/tower_1/conv_1 ( type:  Relu )
# 939/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/Conv2D ( type:  Conv2D )
# 940/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 941/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/control_dependency ( type:  Identity )
# 942/993: Analysing op name: mixed_10/tower_1/mixed/conv_1 ( type:  Relu )
# 943/993: Analysing op name: mixed_10/tower_1/mixed/conv_1/CheckNumerics ( type:  CheckNumerics )
# 944/993: Analysing op name: mixed_10/tower_1/mixed/conv/Conv2D ( type:  Conv2D )
# 945/993: Analysing op name: mixed_10/tower_1/mixed/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 946/993: Analysing op name: mixed_10/tower_1/mixed/conv/control_dependency ( type:  Identity )
# 947/993: Analysing op name: mixed_10/tower_1/mixed/conv ( type:  Relu )
# 948/993: Analysing op name: mixed_10/tower_1/mixed/conv/CheckNumerics ( type:  CheckNumerics )
# 949/993: Analysing op name: mixed_10/tower_1/conv_1/CheckNumerics ( type:  CheckNumerics )
# 950/993: Analysing op name: mixed_10/tower_1/conv/CheckNumerics ( type:  CheckNumerics )
# 951/993: Analysing op name: mixed_10/tower/conv/Conv2D ( type:  Conv2D )
# 952/993: Analysing op name: mixed_10/tower/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 953/993: Analysing op name: mixed_10/tower/conv/control_dependency ( type:  Identity )
# 954/993: Analysing op name: mixed_10/tower/conv ( type:  Relu )
# 955/993: Analysing op name: mixed_10/tower/mixed/conv_1/Conv2D ( type:  Conv2D )
# 956/993: Analysing op name: mixed_10/tower/mixed/conv_1/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 957/993: Analysing op name: mixed_10/tower/mixed/conv_1/control_dependency ( type:  Identity )
# 958/993: Analysing op name: mixed_10/tower/mixed/conv_1 ( type:  Relu )
# 959/993: Analysing op name: mixed_10/tower/mixed/conv_1/CheckNumerics ( type:  CheckNumerics )
# 960/993: Analysing op name: mixed_10/tower/mixed/conv/Conv2D ( type:  Conv2D )
# 961/993: Analysing op name: mixed_10/tower/mixed/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 962/993: Analysing op name: mixed_10/tower/mixed/conv/control_dependency ( type:  Identity )
# 963/993: Analysing op name: mixed_10/tower/mixed/conv ( type:  Relu )
# 964/993: Analysing op name: mixed_10/tower/mixed/conv/CheckNumerics ( type:  CheckNumerics )
# 965/993: Analysing op name: mixed_10/tower/conv/CheckNumerics ( type:  CheckNumerics )
# 966/993: Analysing op name: mixed_10/conv/Conv2D ( type:  Conv2D )
# 967/993: Analysing op name: mixed_10/conv/batchnorm ( type:  BatchNormWithGlobalNormalization )
# 968/993: Analysing op name: mixed_10/conv/control_dependency ( type:  Identity )
# 969/993: Analysing op name: mixed_10/conv ( type:  Relu )
# 970/993: Analysing op name: mixed_10/join ( type:  Concat )
# 971/993: Analysing op name: pool_3 ( type:  AvgPool )
# 972/993: Analysing op name: pool_3/_reshape ( type:  Reshape )
# 973/993: Analysing op name: softmax/logits/MatMul ( type:  MatMul )
# 974/993: Analysing op name: softmax/logits ( type:  BiasAdd )
# Translation to CoreML spec completed. Now compiling and saving the CoreML model.
#
#  Core ML model generated. Saved at location: ./inception_v3.mlmodel
#
# Core ML input(s):
#  [name: "Mul__0"
# type {
#   imageType {
#     width: 299
#     height: 299
#     colorSpace: RGB
#   }
# }
# ]
# Core ML output(s):
#  [name: "softmax__logits__0"
# type {
#   multiArrayType {
#     shape: 1008
#     dataType: DOUBLE
#   }
# }
# ]
